# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0.8,400)
y1 = 1.2198e11/x
y2 = 40e7*x
plt.plot(x,y1,label='Investment')
plt.plot(x,y2,label='Oppourtunity Cost')
plt.xlabel("No. of days for complete vaccination")
plt.xlabel("Cost in crores of INR")
plt.legend()
# Out:
# Text(0.5, 0, 'Cost in crores of INR')
